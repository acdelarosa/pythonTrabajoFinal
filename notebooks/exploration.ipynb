# %%
import pandas as pd
import matplotlib.pyplot as plt 

data_path="../data/processed/cleaned_products.csv"
df=pd.read_csv(data_path)

print("Basics Statistics")
print(df.describe())

plt.hist(df["price"], bins=20, edgecolor="black")
plt.title("Distribución de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()


print("Productos más caros: ")
highestPrice=df.nlargest(3, 'price')
print(highestPrice)
# Out:
# Basics Statistics
#              price
# count     3.000000
# mean    895.993333
# std     682.119762
# min     109.990000
# 25%     677.490000
# 50%    1244.990000
# 75%    1288.995000
# max    1333.000000
# Productos más caros:
#               title                                        description  \
# 0  Apple MacBook...  Apple MacBook Pro 13" Space Gray, Core i5 2.3G...
# 1     ThinkPad X230  12.5", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pr...
# 2           Nokia X                             Andoid, Jolla dualboot
#
#      price
# 0  1333.00
# 1  1244.99
# 2   109.99
